# %% [markdown]
# # Pfizer/Moderna Validation Studies

# %% [markdown]
# ## File Description
#
# In this jupyter notebook, we will evaluate our LNP prediction xgboost model on a pfizer's and moderna's clinically relevant LNP formulations with varying components ratios.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
from sklearn import svm
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
#from sklearn.neighbors.nca import NeighborhoodComponentsAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.manifold import TSNE

from sklearn import model_selection
from sklearn.model_selection import KFold
import xgboost as xgb
import random
from imblearn.over_sampling import SMOTE, ADASYN, BorderlineSMOTE, SVMSMOTE, SMOTENC, KMeansSMOTE, RandomOverSampler
from imblearn.combine import SMOTEENN, SMOTETomek
from collections import Counter
from mpl_toolkits.mplot3d import Axes3D
from time import time
from sklearn import manifold
from matplotlib.ticker import NullFormatter
import operator, itertools 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from rdkit import Chem
from mordred import Calculator, descriptors
from tqdm import tqdm
import pickle
import ast

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.weight'] = 'normal' 
plt.rcParams['font.sans-serif'] = 'Avenir'#[FONTNAME]

# %% [markdown]
# ## Loading data

# %%
model_name = 'mRNA'

data_train = pd.read_csv('../../Datasets/Drug-Based/mRNA_train.csv')

data_test = pd.read_csv('../../Datasets/Drug-Based/mRNA_test.csv')

pfizer_data = pd.read_csv('../../Datasets/Drug-Based/Pfizer&Moderna/pfizer_validation.csv')

moderna_data = pd.read_csv('../../Datasets/Drug-Based/Pfizer&Moderna/moderna_validation.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 model_name = 'mRNA'
# ----> 3 data_train = pd.read_csv('../../Datasets/Drug-Based/mRNA_train.csv')
#       5 data_test = pd.read_csv('../../Datasets/Drug-Based/mRNA_test.csv')
#       7 pfizer_data = pd.read_csv('../../Datasets/Drug-Based/Pfizer&Moderna/pfizer_validation.csv')
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      48 kwds["usecols"] = self.usecols
#      50 # open handles
# ---> 51 self._open_handles(src, kwds)
#      52 assert self.handles is not None
#      54 # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     218 def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     219     """
#     220     Let the readers open IOHandles after they are done with their potential raises.
#     221     """
# --> 222     self.handles = get_handle(
#     223         src,
#     224         "r",
#     225         encoding=kwds.get("encoding", None),
#     226         compression=kwds.get("compression", None),
#     227         memory_map=kwds.get("memory_map", False),
#     228         storage_options=kwds.get("storage_options", None),
#     229         errors=kwds.get("encoding_errors", "strict"),
#     230     )
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Datasets/Drug-Based/mRNA_train.csv'

# %%
pfizer_data

# %% [markdown]
# ## Utilities

# %%
def display_full(df):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(df)

# %% [markdown]
# ## Preprocessing

# %%
#Drop Payload if not multidrug model
if model_name not in ['multidrug','RNA'] :
    data_train = data_train.drop(['Payload'],1)
    data_test = data_test.drop(['Payload'],1)
    
data_train = data_train.drop(['diameter'],1)
data_test = data_test.drop(['diameter'],1)

#Separate X and y
y_train = np.array(data_train['label'])
X_train = data_train.drop(['label','Lipomer', 'Cholesterol', 'HelperLipid', 'PEGChain', 'PEG MW'], 1)
y_test = np.array(data_test['label'])
X_test = data_test.drop(['label','Lipomer', 'Cholesterol', 'HelperLipid', 'PEGChain', 'PEG MW'], 1)
 
y_pfizer = np.array(pfizer_data['label'])
X_pfizer = pfizer_data.drop(['label','Lipomer', 'Cholesterol', 'HelperLipid', 'PEG'], 1)
y_moderna = np.array(data_train['label'])
X_moderna = moderna_data.drop(['label','Lipomer', 'Cholesterol', 'HelperLipid', 'PEG'], 1)

# %% [markdown]
# ## Appending SMILES

# %%
Smiles = pd.read_csv('../../Datasets/Smiles_pfizer_moderna.csv')
cols = ['Name','SMILES']
Smiles = Smiles[cols]
Smiles = Smiles.drop_duplicates('Name')

Smiles
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 Smiles = pd.read_csv('../../Datasets/Smiles_pfizer_moderna.csv')
#       2 cols = ['Name','SMILES']
#       3 Smiles = Smiles[cols]
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      48 kwds["usecols"] = self.usecols
#      50 # open handles
# ---> 51 self._open_handles(src, kwds)
#      52 assert self.handles is not None
#      54 # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     218 def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     219     """
#     220     Let the readers open IOHandles after they are done with their potential raises.
#     221     """
# --> 222     self.handles = get_handle(
#     223         src,
#     224         "r",
#     225         encoding=kwds.get("encoding", None),
#     226         compression=kwds.get("compression", None),
#     227         memory_map=kwds.get("memory_map", False),
#     228         storage_options=kwds.get("storage_options", None),
#     229         errors=kwds.get("encoding_errors", "strict"),
#     230     )
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/pandas/io/common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Datasets/Smiles_pfizer_moderna.csv'

# %%
def add_smiles(data,smiles):
    cols_to_smiles = ['Lipomer','Cholesterol','HelperLipid', 'PEG']
    for col in cols_to_smiles:
        data = data.join(smiles.set_index('Name'), on=col)
        print('---',col,'SMILES Unknown---')
        print(np.unique(data.loc[data.SMILES.isnull(),col]))
        new_name = col + ' SMILES'
        data = data.rename(columns = {'SMILES': new_name})

    print('---Number of rows without any NaN SMILES---')
    nonnull = data[data['Lipomer SMILES'].isnull() == False]
    nonnull = nonnull[nonnull['Cholesterol SMILES'].isnull() == False]
    nonnull = nonnull[nonnull['HelperLipid SMILES'].isnull() == False]
    nonnull = nonnull[nonnull['PEG SMILES'].isnull() == False]
    print(len(nonnull))
    data = nonnull.reset_index(drop = True)
    return data

pfizer_data = add_smiles(pfizer_data,Smiles)
pfizer_data = pfizer_data.drop(columns = ['Lipomer', 'Cholesterol', 'HelperLipid', 'PEG'])

pfizer_data.to_csv('../../Datasets/Drug-Based/Pfizer&Moderna/Smiles_pfizer.xlsx') 

pfizer_data
# Out:
# --- Lipomer SMILES Unknown---
# []
# --- Cholesterol SMILES Unknown---
# []
# --- HelperLipid SMILES Unknown---
# []
# --- PEG SMILES Unknown---
# []
# ---Number of rows without any NaN SMILES---
# 48
#     label  Mass Ratio  Lipomer Mole %  Cholesterol Mole %  PEG Mole %  \
# 0       1        15.0            40.0                42.7        1.60
# 1       1        15.0            42.5                42.7        1.60
# 2       1        15.0            45.0                42.7        1.60
# 3       1        15.0            46.3                42.7        1.60
# 4       1        15.0            47.5                42.7        1.60
# 5       1        15.0            50.0                42.7        1.60
# 6       1        15.0            52.5                42.7        1.60
# 7       1        15.0            55.0                42.7        1.60
# 8       1        15.0            57.5                42.7        1.60
# 9       1        15.0            60.0                42.7        1.60
# 10      1        15.0            46.3                25.0        1.60
# 11      1        15.0            46.3                27.5        1.60
# 12      1        15.0            46.3                30.0        1.60
# 13      1        15.0            46.3                32.5        1.60
# 14      1        15.0            46.3                35.0        1.60
# 15      1        15.0            46.3                37.5        1.60
# 16      1        15.0            46.3                40.0        1.60
# 17      1        15.0            46.3                42.5        1.60
# 18      1        15.0            46.3                42.7        1.60
# 19      1        15.0            46.3                45.0        1.60
# 20      1        15.0            46.3                42.7        0.25
# 21      1        15.0            46.3                42.7        0.50
# 22      1        15.0            46.3                42.7        0.75
# 23      1        15.0            46.3                42.7        1.00
# 24      1        15.0            46.3                42.7        1.25
# 25      1        15.0            46.3                42.7        1.50
# 26      1        15.0            46.3                42.7        1.60
# 27      1        15.0            46.3                42.7        1.75
# 28      1        15.0            46.3                42.7        2.00
# 29      1        15.0            46.3                42.7        1.60
# 30      1        15.0            46.3                42.7        1.60
# 31      1        15.0            46.3                42.7        1.60
# 32      1        15.0            46.3                42.7        1.60
# 33      1        15.0            46.3                42.7        1.60
# 34      1        15.0            46.3                42.7        1.60
# 35      1        15.0            46.3                42.7        1.60
# 36      1        15.0            46.3                42.7        1.60
# 37      1        15.0            46.3                42.7        1.60
# 38      1        15.0            46.3                42.7        1.60
# 39      1         5.0            50.0                38.5        1.50
# 40      1         7.5            50.0                38.5        1.50
# 41      1        10.0            50.0                38.5        1.50
# 42      1        12.5            50.0                38.5        1.50
# 43      1        15.0            50.0                38.5        1.50
# 44      1        17.5            50.0                38.5        1.50
# 45      1        20.0            50.0                38.5        1.50
# 46      1        22.5            50.0                38.5        1.50
# 47      1        25.0            50.0                38.5        1.50
#
#     Helper Lipid Mole %  Payload  \
# 0                   9.4        0
# 1                   9.4        0
# 2                   9.4        0
# 3                   9.4        0
# 4                   9.4        0
# 5                   9.4        0
# 6                   9.4        0
# 7                   9.4        0
# 8                   9.4        0
# 9                   9.4        0
# 10                  9.4        0
# 11                  9.4        0
# 12                  9.4        0
# 13                  9.4        0
# 14                  9.4        0
# 15                  9.4        0
# 16                  9.4        0
# 17                  9.4        0
# 18                  9.4        0
# 19                  9.4        0
# 20                  9.4        0
# 21                  9.4        0
# 22                  9.4        0
# 23                  9.4        0
# 24                  9.4        0
# 25                  9.4        0
# 26                  9.4        0
# 27                  9.4        0
# 28                  9.4        0
# 29                  0.0        0
# 30                  2.5        0
# 31                  5.0        0
# 32                  7.5        0
# 33                  9.4        0
# 34                 10.0        0
# 35                 12.5        0
# 36                 15.0        0
# 37                 17.5        0
# 38                 20.0        0
# 39                 10.0        0
# 40                 10.0        0
# 41                 10.0        0
# 42                 10.0        0
# 43                 10.0        0
# 44                 10.0        0
# 45                 10.0        0
# 46                 10.0        0
# 47                 10.0        0
#
#                                        Lipomer SMILES  \
# 0   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 1   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 2   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 3   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 4   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 5   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 6   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 7   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 8   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 9   OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 10  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 11  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 12  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 13  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 14  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 15  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 16  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 17  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 18  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 19  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 20  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 21  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 22  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 23  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 24  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 25  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 26  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 27  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 28  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 29  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 30  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 31  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 32  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 33  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 34  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 35  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 36  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 37  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 38  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 39  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 40  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 41  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 42  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 43  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 44  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 45  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 46  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
# 47  OCCCCN(CCCCCCOC(C(CCCCCC)CCCCCCCC)=O)CCCCCCOC(...
#
#                                    Cholesterol SMILES  \
# 0   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 1   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 2   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 3   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 4   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 5   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 6   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 7   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 8   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 9   CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 10  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 11  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 12  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 13  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 14  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 15  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 16  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 17  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 18  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 19  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 20  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 21  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 22  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 23  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 24  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 25  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 26  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 27  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 28  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 29  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 30  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 31  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 32  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 33  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 34  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 35  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 36  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 37  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 38  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 39  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 40  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 41  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 42  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 43  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 44  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 45  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 46  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
# 47  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...
#
#                                    HelperLipid SMILES  \
# 0   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 1   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 2   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 3   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 4   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 5   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 6   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 7   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 8   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 9   [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 10  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 11  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 12  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 13  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 14  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 15  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 16  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 17  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 18  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 19  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 20  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 21  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 22  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 23  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 24  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 25  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 26  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 27  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 28  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 29  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 30  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 31  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 32  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 33  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 34  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 35  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 36  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 37  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 38  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 39  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 40  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 41  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 42  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 43  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 44  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 45  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 46  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
# 47  [H][C@@](COP(OCC[N+](C)(C)C)([O-])=O)(OC(CCCCC...
#
#                                     PEG SMILES
# 0   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 1   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 2   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 3   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 4   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 5   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 6   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 7   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 8   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 9   COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 10  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 11  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 12  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 13  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 14  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 15  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 16  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 17  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 18  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 19  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 20  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 21  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 22  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 23  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 24  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 25  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 26  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 27  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 28  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 29  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 30  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 31  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 32  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 33  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 34  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 35  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 36  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 37  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 38  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 39  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 40  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 41  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 42  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 43  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 44  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 45  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 46  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O
# 47  COCCOCC(N(CCCCCCCCCCCCCC)CCCCCCCCCCCCCC)=O

# %%
#contains only unique pairs of molecules
with open('../../Datasets/dimer_interactions_minenergy.pkl', 'rb') as f:
    try:
        interactions = pickle.load(f)
    except EOFError:
        interactions = pd.DataFrame({})
        print('error')

# %%
interactions
# Out:
#                                                      A  \
# 0    C=CC(N(C(O)(OCCCCCCCCCCCC)C=C)CCN(CCN(C(O)(OCC...
# 1    CC(C(N(C(O)(OCCCCCCCCCCCCCCCCCC)C(C)=C)CCN(CCN...
# 2    CC(CNCC(CCCCCCCCCC)O)(C)CN(CC(CCCCCCCCCC)O)CC(...
# 3    CCCCC/C=C\C/C=C\CCCCCCCC(OCC(COC(C1=CC=C(B(O)O...
# 4    CCCCC/C=C\C/C=C\CCCCCCCC(OCC(COC(C1=CC=C(N=CC=...
# ..                                                 ...
# 260  O[C@H](CCCCCCCCCCCC)CN(C[C@@H](CCCCCCCCCCCC)O)...
# 261  O[C@H](CCCCCCCCCCCC)CN(C[C@@H](CCCCCCCCCCCC)O)...
# 262  O[C@H](CCCCCCCCCCCCC)CN(C[C@@H](CCCCCCCCCCCCC)...
# 263  O[C@H](CCCCCCCCCCCCC)CN(C[C@@H](CCCCCCCCCCCCC)...
# 264  [OH]C([N](C(C=C)([NH]CCCCCCCCCCCC)[OH])CC[N](C...
#
#                                                      B       Total  \
# 0    CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...  385.611896
# 1    CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...  546.625396
# 2    CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...   40.474225
# 3    CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...   46.326843
# 4    CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...   48.456493
# ..                                                 ...         ...
# 260  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...  110.752617
# 261  CC(CCC[C@@](C)(O)[C@@](CC[C@]1([C@](CC=C2C[C@@...  111.146858
# 262  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...  125.383084
# 263  CC(CCC[C@@](C)(O)[C@@](CC[C@]1([C@](CC=C2C[C@@...  125.710687
# 264  CC(CCC[C@@H](C)[C@@](CC[C@]1([C@](CC=C2C[C@@](...  394.750035
#
#            Elst       Exch        Ind        Disp
# 0    200.512255 -12.402724  10.270486  187.231879
# 1    277.144680 -28.444028  18.883688  279.041055
# 2     25.067708   3.527142  -1.287359   13.166734
# 3     26.729478   2.992732  -0.473313   17.077946
# 4     27.578637   2.989245  -0.270520   18.159131
# ..          ...        ...        ...         ...
# 260   62.016920   4.168789   0.497316   44.069592
# 261   62.072246   4.310329   0.675872   44.088411
# 262   68.395000   2.710323   1.391823   52.885938
# 263   68.331610   2.869166   1.551021   52.958890
# 264  203.071780 -15.567226  12.020330  195.225151
#
# [265 rows x 7 columns]

# %% [markdown]
# # Binary Classification using traditional ML techniques - XGBoost

# %%
clf_VERSION = 'v1'
K = 5 # 5 fold cv

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (5,3))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = np.array(cm)
        cm = np.around(cm/cm.sum(axis=1)[:, None]*100).astype('int')
        print("Percentage confusion matrix")
        print(cm.sum(axis=1))
    else:
        print('Confusion matrix, without normalization')

#    print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    return


def show_confusion_matrix(y, pred_array):
    y = np.array(y).astype(int)
    y_pred = np.array(pred_array)

    cnf_matrix = confusion_matrix(y, y_pred)
    np.set_printoptions(precision=2)
    sorted_cnf_matrix = cnf_matrix
    class_names = ['Unstable', 'Stable'] #[0, 1]

    plot_confusion_matrix(sorted_cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
    #plt.show()
    #file_name = 'Confmat_siRNAmodel_mRNApayload.svg'
    file_name = 'test.svg'
    plt.savefig('../../Figures/Drug-Based Charts/Confusion Matrices/' + file_name)
    return


def sigmoid(x):
    return 1 / (1 + math.exp(-x))

def get_auc_plot(y, scores):
    y = np.array(y).astype(int)
    fpr, tpr, thresholds = metrics.roc_curve(y, scores)
#    print(fpr, tpr, thresholds)
    # Getting accuracy, sensitivity and accuracy plot for varying thresholds. 
    accuracy_array = []
    sensitivity_array = [x*100 for x in tpr]
    specificity_array = [(1-x)*100 for x in fpr]#(1-fpr)*100
    for i, th in enumerate(thresholds):
        pred_array = []
        for s in scores:
            if s>th:
                pred_array.append(1)
            else:
                pred_array.append(0)
        accuracy_array.append(accuracy_score(y, pred_array))
#         print('For threshold : ', th, '->', ' Accuracy ', accuracy_array[i], 
#               ' Sensitivity ', sensitivity_array[i], 'specificity ', specificity_array[i])
#         show_confusion_matrix(y, pred_array)
#     print('accuracy_array', accuracy_array)
#     print('sensitivity_array', sensitivity_array)
#     print('specificity_array', specificity_array)
#     print('thresholds_array', thresholds)
    
    roc_auc = metrics.auc(fpr, tpr)
    #plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = f"AUC = {np.round(roc_auc,3):0.3f}")
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([-0.001, 1])
    plt.ylim([0, 1.001])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    #plt.show()
    #file_name = 'AUC_siRNAmodel_mRNApayload.svg'
    file_name = 'test.svg'
    plt.savefig('../../Figures/Drug-Based Charts/AUC Curves/' + file_name)
    for i in range(len(fpr)):
        if fpr[i] > 0.01:
            break
    return roc_auc, tpr[i], fpr[i]

def get_auc(y, scores):
    y = np.array(y).astype(int)
    fpr, tpr, thresholds = metrics.roc_curve(y, scores)
    roc_auc = metrics.auc(fpr, tpr)

    for i in range(len(fpr)):
        if fpr[i] > 0.01:
            break
    return roc_auc, tpr[i], fpr[i]


def trainXGB(Xtrain, ytrain, Xtest, ytest, importance_array, column_names, hyperparameters, verbose):
    dtrain = xgb.DMatrix(Xtrain,label=ytrain)
    dtest = xgb.DMatrix(Xtest,label=ytest)
    print('Setting XGB params')
    evallist  = [(dtest,'test'), (dtrain,'train')]
    num_round = 220#60
    print('training the XGB classifier')
    bst = xgb.train(hyperparameters, dtrain, num_round, evallist, early_stopping_rounds=100, verbose_eval=False)
    #print('training completed, printing the relative importance: \
    #      (feature id: importance value)')
    importance = bst.get_fscore()
    importance = sorted(importance.items(), key=operator.itemgetter(1))
    
    # we will print from df1 dataframe, getting the corresponding feature names. 
    df1 = pd.DataFrame(importance, columns=['feature', 'fscore'])
    # Normalizing the feature scores
    df1['fscore'] = df1['fscore'] / df1['fscore'].sum()
    
    # adding a column of feature name
    #column_names = df.columns[:-1]
    print('check size of col names: ',len(column_names))
    df1['feature_names'] = pd.Series([column_names[int(f[0].replace("f", ""))] for f in importance])
    
    #Take Top 30
    #df1 = df1.sort_values(by=['feature'])
    importance_array = df1.copy()
    df1 = df1.nlargest(30, 'fscore')
    
    #Group into categories
    df2 = importance_array.copy()
    df2['group'] = 'Lipomer Atomic Properties'
    components = ['Lipomer','Cholesterol','Helper Lipid', 'PEG']
    interactions = ['Total', 'Ind', 'Elst', 'Exch','Disp']
    for mol in components:
        mol_strip = mol.replace(" ", "")
        df2.loc[df2['feature_names'].str.endswith(mol_strip), 'group'] = mol + " Atomic Properties"
        df2.loc[df2['feature_names'] == mol + " Mole %", 'group'] = mol + " Molar Composition"
    df2.loc[df2['feature_names'].isin(interactions), 'group'] = 'Lipomer-Cholesterol Interaction Energies'
    df2.loc[df2['feature_names'] == "Mass Ratio", 'group'] = "Lipomer-PEG Mass Ratio"
    df2 = df2[['group','fscore']].groupby(['group']).agg(['sum'])
    df2.columns = ['_'.join(str(i) for i in col) for col in df2.columns]
    df2 = df2.reset_index(level='group')
    #print(df2)
    
#     #Filter specific importance values
#     relevant_feats = ["Lipomer Mole %","Cholesterol Mole %", "Helper Lipid Mole %", "PEG Mole %", "Total", "Ind", "Elst", "Exch", "Disp", "MassRatio"]
#     df1_filt = df1.loc[df1.feature_names.isin(relevant_feats)]
        
    if verbose:
#         df1_filt.sort_values(by='fscore',ascending=True).plot(kind='barh', x='feature_names', y='fscore', legend=False)
#         #plt.title('XGBoost Feature Importance (Top 30)')
#         plt.ylabel('')
#         plt.xlabel('Relative Importance')
#         plt.savefig('FeatImp_mRNA_full.svg')
#         plt.show()
        
        #Feature Importance Plot
        df2.sort_values(by='fscore_sum',ascending=True).plot(kind='barh', x='group', y='fscore_sum', legend=False)
        #plt.title('XGBoost Feature Importance (Top 30)')
        plt.ylabel('')
        plt.xlabel('Relative Importance')
        file_name = 'FeatImp_RNA.svg'
        plt.savefig('../../Figures/Drug-Based Charts/Feature Importance/' + file_name)
        plt.show()
        
        #Export Feature Importance to Excel
        #df2.to_excel('../../Figures/Drug-Based Charts/Feature Importance/FeatImport_RNA_grouped.xlsx')  
        #importance_array.to_excel('../../Figures/Drug-Based Charts/Feature Importance/FeatImport_RNA_full.xlsx') 
        
#    print 'Saving the models'
#    bst.save_model(name+'_xgb_v'+clf_VERSION+'.model')
#    bst.dump_model(name+'_xgb_v'+clf_VERSION+'_dump.raw.txt')
#    bst.dump_model(name+'_xgb_v'+clf_VERSION+'_dump.raw.txt',name+'_xgb_v'+clf_VERSION+'_featmap.txt')
    return bst, importance_array


def classifier_train(X, y, runXGB, Xtest, ytest, pca_comp, smote, importance_array, column_names, hyperparameters, verbose): # pca = 0 means no PCA applied
    print('Normalising the input data...')
    scaler = StandardScaler()
    scaler.fit(X)  
    scaledX = scaler.transform(X)
    if smote == 1:
        X_resampled, y_resampled = SMOTE().fit_resample(np.array(scaledX), y.astype(int))
        #(SMOTE, ADASYN, BorderlineSMOTE, SVMSMOTE, SMOTENC, KMeansSMOTE, RandomOverSampler, SMOTEENN, SMOTETomek)
        scaledX = X_resampled#pd.DataFrame(X_resampled, columns = data.columns)
        y = y_resampled #pd.DataFrame(pd.Series(y_resampled, name='label'))
    if pca_comp != 0:
        pca = PCA(n_components = pca_comp)
        pca.fit(scaledX)
        pca_scaledX = pca.transform(scaledX)
    else:
        pca_scaledX = scaledX
        pca =0

    if runXGB == 1:
        print('Running the XGB classifier')
        clf, importance_array = trainXGB(pca_scaledX, y, scaler.transform(Xtest), ytest, importance_array, column_names, hyperparameters, verbose)
        index = 1
    return pca_scaledX, y, scaler, pca, clf, index, importance_array, column_names


def classifier_test(scaledX, y, clf, index, scaler, pca, verbose):
    pca_scaledX = scaledX
    if pca != 0:
        pca_scaledX = pca.transform(scaledX)
    if index==1:# XGB
        pca_scaledXG = xgb.DMatrix(pca_scaledX, label=y)
        pred_array = clf.predict(pca_scaledXG, ntree_limit=clf.best_iteration)
        #.reshape(y.shape[0], NUM_CLASS)#, ntree_limit=clf.best_iteration)
        scores = pred_array

#    auc = get_auc(y, scores)
    if verbose:
        auc = get_auc_plot(y, scores)
    else:
        auc = get_auc(y, scores)
    # Compute confusion matrix
#    show_confusion_matrix(y, pred_array)
    return pred_array, auc, clf# error

def feature_selection(Xtrain, Xtest, importance_array, column_names, verbose):
    imp_vals = importance_array
    imp_vals['feature'] = imp_vals['feature'].map(lambda k: k.replace("f",""))
    imp_vals['feature'] = imp_vals['feature'].astype(int)
    imp_vals['fscore'] = imp_vals['fscore'].astype(float)
    imp_vals = imp_vals.sort_values('feature')
    if verbose:
        print('---importance values---')
        print('max:',np.max(imp_vals.iloc[:,1]))
        print('min:',np.min(imp_vals.iloc[:,1]))
        print('mean:',np.mean(imp_vals.iloc[:,1]))
    #threshold importance
    threshold = 0 #threshold on fscore sum of all 5 folds 0.007, 
    imp_vals = imp_vals.loc[imp_vals['fscore'] > threshold] #threshold importance
    filt = imp_vals.to_numpy()[:,0].astype(int)
    
    #threshold number of features
#     num_feat = 234
#     imp_vals = imp_vals.nlargest(num_feat,'fscore')
#     filt = imp_vals.to_numpy()[:,0].astype(int)
    
    #filter both training and testing data
    column_names = column_names[filt]
    Xtrain_filt = np.array(Xtrain)[:, filt]
    Xtest_filt = np.array(Xtest)[:, filt]
    
    if verbose:
        print('Before Feat Sel: ',Xtrain.shape[1],' features')
        print('After Feat Sel: ',Xtrain_filt.shape[1],' features')
        print('------------------------')
    return filt, Xtrain_filt, Xtest_filt, column_names
    
def pandas_classifier(df, runXGB, K, importance_array, hyperparameters, verbose = True):
    print('Performing ' + str(K) + '-fold cross validation')
    auc_fold = []
    acc_fold = []
    for k in range(K):# performing K fold validation
        #if k == 0: # running only for k'th fold
            print('Fold_num = ' + str(k))
            training_rows = [i for i in range(len(df)) if i%K!=k]
            datatrain = df.loc[training_rows] # training
            testing_rows = [i for i in range(len(df)) if i%K==k]
            datatest = df.loc[testing_rows] # taking every k'th example for test
            Xtrain = datatrain.iloc[:, 0:-1]
            ytrain = datatrain.iloc[:, -1]
            Xtest = datatest.iloc[:, 0:-1]
            ytest = datatest.iloc[:, -1]
            print('--------------------------------------------------------------')
            print('Calling the classifier to train')
            importance_array = pd.DataFrame()
            Xtrain_scaled, ytrain, scaler, pca, clf, index, importance_array, column_names = classifier_train(Xtrain, ytrain, runXGB, Xtest, ytest, 0, 1, importance_array, Xtrain.columns, hyperparameters, verbose)
            print('Feature selection using training feature importance')
            Xtest_scaled = scaler.transform(Xtest)
            imp_features, Xtrain_scaled, Xtest_scaled, column_names = feature_selection(Xtrain_scaled, Xtest_scaled, importance_array, column_names, verbose)
            print('Repeat training on filtered training data')
            importance_array = pd.DataFrame()
            clf, importance_array = trainXGB(Xtrain_scaled, ytrain, Xtest_scaled, ytest, importance_array, column_names, hyperparameters, verbose)
            print('Analysing the test predictions for fold num ', k)
            pred_array, auc, clf = classifier_test(Xtest_scaled, ytest, clf, index, scaler, 0, verbose)
            auc_fold.append(auc[0])
            print('test auc = '+str(auc[0]) )
            accuracy = accuracy_score(ytest.astype(int), np.round(pred_array))
            acc_fold.append(accuracy)
            print("Accuracy: %.2f%%" % (accuracy * 100.0))
            if verbose:
                show_confusion_matrix(ytest, np.round(pred_array))
            print('------------------------------------------------------------')
    if K != 0:
        print('************************************************************************')
        print(auc_fold)#, sum(np.array(auc_fold))/int(K))
        print('Average '+str(K)+' fold CV AUC= ', str(sum(np.array(auc_fold))/int(K)))
        print('Average '+str(K)+' fold CV Accuracy= ', str(sum(np.array(acc_fold))/int(K)))
        print('************************************************************************')
    print('Training the classifier on complete train dataset to get IMP features')
    Xtrain_full, ytrain_full, scaler, pca, clf, index, importance_array, column_names = classifier_train(df.iloc[:, 0:-1], df.iloc[:, -1],
                                               runXGB, df.iloc[:, 0:-1], df.iloc[:, -1], 0, 1, importance_array, df.iloc[:, 0:-1].columns, hyperparameters, verbose)
    return importance_array, sum(np.array(auc_fold))/int(K), sum(np.array(acc_fold))/int(K)

# %% [markdown]
# ## Test Final Model

# %%
def train_model(X_train, y_train, X_val, y_val, random_search_params):
    #Parameters
    np.random.seed(15)
    random.seed(15)
    importance_array = pd.DataFrame()
    runXGB = 1
    pca = 0 #broken
    smote = 1
    verbose = True

    #Training
    X_train, y_train, scaler, pca, clf, index, importance_array, column_names = classifier_train(X_train, y_train, runXGB, X_val, y_val, pca, smote, importance_array, X_train.columns, random_search_params, verbose)
    print('Feature selection using training feature importance')
    X_val = scaler.transform(X_val)
    imp_features, X_train, X_val, column_names = feature_selection(X_train, X_val, importance_array, column_names, verbose)
    print('Repeat training on filtered training data')
    importance_array = pd.DataFrame()
    clf, importance_array = trainXGB(X_train, y_train, X_val, y_val, importance_array, column_names, random_search_params, verbose)
    return clf, index, scaler, pca, imp_features, verbose
                
def test_model(X_test, y_test, clf, index, scaler, pca, imp_features, verbose):
    #Testing
    print('Analysing the test predictions')
    X_test = scaler.transform(X_test)
    X_test = np.array(X_test)[:, imp_features]
    pred_array, auc, clf = classifier_test(X_test, y_test, clf, index, scaler, pca, verbose)

    #Evaluation
    print('test auc = '+str(auc[0]) )
    accuracy = accuracy_score(y_test.astype(int), np.round(pred_array))
    print("Accuracy: %.2f%%" % (accuracy * 100.0))
    show_confusion_matrix(y_test, np.round(pred_array))
    return pred_array

# %%
#Load Results
name = model_name
random_results = pd.read_csv('./params/RS_results_'+name+'.csv')

# with open('./params/hyperparameters'+name+'.pkl', 'rb') as f:
#     random_search_params = pickle.load(f)

#Select different parameters
rank = 0
random_search_params = ast.literal_eval(random_results.loc[rank, 'params'])

print(random_search_params)
random_results
# Out:
# {'eta': 0.07, 'max_depth': 9, 'gamma': 0.3, 'alpha': 5, 'lambda': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'objective': 'binary:logistic', 'min_child_weight': 1, 'verbosity': 0, 'nthread': 6, 'eval_metric': 'auc', 'seed': 15, 'scale_pos_weight': 3}
#     index       auc  accuracy  \
# 0      53  0.810511  0.810511
# 1      98  0.810270  0.810270
# 2       9  0.810187  0.810187
# 3      36  0.809868  0.809868
# 4      65  0.809700  0.809700
# ..    ...       ...       ...
# 95     66  0.776219  0.776219
# 96     78  0.772417  0.772417
# 97     73  0.771174  0.771174
# 98     10  0.766388  0.766388
# 99      1  0.764233  0.764233
#
#                                                params  iteration
# 0   {'eta': 0.07, 'max_depth': 9, 'gamma': 0.3, 'a...         53
# 1   {'eta': 0.07, 'max_depth': 9, 'gamma': 0.0, 'a...         98
# 2   {'eta': 0.12, 'max_depth': 6, 'gamma': 0.1, 'a...          9
# 3   {'eta': 0.14, 'max_depth': 8, 'gamma': 0.0, 'a...         36
# 4   {'eta': 0.1, 'max_depth': 8, 'gamma': 0.0, 'al...         65
# ..                                                ...        ...
# 95  {'eta': 0.01, 'max_depth': 3, 'gamma': 0.4, 'a...         66
# 96  {'eta': 0.01, 'max_depth': 3, 'gamma': 0.2, 'a...         78
# 97  {'eta': 0.01, 'max_depth': 3, 'gamma': 0.4, 'a...         73
# 98  {'eta': 0.01, 'max_depth': 3, 'gamma': 0.3, 'a...         10
# 99  {'eta': 0.01, 'max_depth': 3, 'gamma': 0.1, 'a...          1
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Pfizer Validation

# %% [markdown]
# ### Train Model

# %%
clf, index, scaler, pca, imp_features, verbose  = train_model(X_train, y_train, X_test, y_test, random_search_params)
# Out:
# Normalising the input data...
# Running the XGB classifier
# Setting XGB params
# training the XGB classifier
# check size of col names:  5852
# Feature selection using training feature importance
# ---importance values---
# max: 0.08929599079225015
# min: 9.59140610013428e-05
# mean: 0.0007800312012480285
# Before Feat Sel:  5852  features
# After Feat Sel:  1282  features
# ------------------------
# Repeat training on filtered training data
# Setting XGB params
# training the XGB classifier
# check size of col names:  1282

# %% [markdown]
# ### Test Model

# %%
y_pred = test_model(X_pfizer, y_pfizer, clf, index, scaler, pca, imp_features, verbose)

#Append y_pred to original dataset
predictions = pfizer_data.iloc[:,:11]
predictions.insert(0, 'prediction', np.round(y_pred).astype(int))
predictions.to_csv('../../Results/pfizer_predictions'+'.csv', index=False)
# Out:
# Analysing the test predictions
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 y_pred = test_model(X_pfizer, y_pfizer, clf, index, scaler, pca, imp_features, verbose)
#       3 #Append y_pred to original dataset
#       4 predictions = pfizer_data.iloc[:,:11]
#
# Input In [9], in test_model(X_test, y_test, clf, index, scaler, pca, imp_features, verbose)
#      21 def test_model(X_test, y_test, clf, index, scaler, pca, imp_features, verbose):
#      22     #Testing
#      23     print('Analysing the test predictions')
# ---> 24     X_test = scaler.transform(X_test)
#      25     X_test = np.array(X_test)[:, imp_features]
#      26     pred_array, auc, clf = classifier_test(X_test, y_test, clf, index, scaler, pca, verbose)
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:883, in StandardScaler.transform(self, X, copy)
#     880 check_is_fitted(self)
#     882 copy = copy if copy is not None else self.copy
# --> 883 X = self._validate_data(X, reset=False,
#     884                         accept_sparse='csr', copy=copy,
#     885                         estimator=self, dtype=FLOAT_DTYPES,
#     886                         force_all_finite='allow-nan')
#     888 if sparse.issparse(X):
#     889     if self.with_mean:
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/sklearn/base.py:437, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     434     out = X, y
#     436 if check_params.get('ensure_2d', True):
# --> 437     self._check_n_features(X, reset=reset)
#     439 return out
#
# File ~/opt/anaconda3/envs/LNP_Predictions/lib/python3.9/site-packages/sklearn/base.py:365, in BaseEstimator._check_n_features(self, X, reset)
#     362     return
#     364 if n_features != self.n_features_in_:
# --> 365     raise ValueError(
#     366         f"X has {n_features} features, but {self.__class__.__name__} "
#     367         f"is expecting {self.n_features_in_} features as input.")
#
# ValueError: X has 6 features, but StandardScaler is expecting 5852 features as input.

# %% [markdown]
# ### Test Model on Other Tests Sets

# %%
models = ['mRNA', 'siRNA']#, 'bcDNA', 'multidrug', 'RNA']#, 'RNA2']
models.remove(model_name) #Remove model's actual test set

for model in models:
    print('----------------------------'+model+'----------------------------')
    data_test2 = pd.read_csv('../../Datasets/Drug-Based/'+model+'_test.csv')

    #Drop Payload if not multidrug model
    if model_name not in ['multidrug','RNA']:
        data_test2 = data_test2.drop(['Payload'],1)

    #Separate X and y
    y_test2 = np.array(data_test2['label'])
    X_test2 = data_test2.drop(['label','Lipomer', 'Cholesterol', 'HelperLipid', 'PEGChain', 'PEG MW', 'diameter'], 1)

    test_model(X_test2, y_test2, clf, index, scaler, pca, imp_features, verbose)
# Out:
# ----------------------------mRNA----------------------------
# Analysing the test predictions
# test auc = 0.5442988832353135
# Accuracy: 72.71%
# Confusion matrix, without normalization

# %% [markdown]
# #### Reset Data

# %%
#Use this cell to reset data
data = reset.copy()
y = reset_y.copy()
#importance_array = orig_importance.copy()
