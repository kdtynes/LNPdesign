# %% [markdown]
# ## Scratch Paper

# %%
import numpy as np
import pandas as pd
import sys

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e5f28aadf8d0> in <module>
# ----> 1 os.cwd()
#
# AttributeError: module 'os' has no attribute 'cwd'

# %%
payload = 'mRNA'
data_dir = ''
data = pd.read_csv
